# %% [markdown]
# <a href="https://colab.research.google.com/github/Rana-Shukor/vector1/blob/main/Copy_of_dotproduct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1: Dot Product Operation using NumPy

import numpy as np

# Question: What is the dot product operation, and how is it implemented in NumPy?
#The dot product (also known as the scalar product) of two vectors is a way to multiply them together to get a scalar.
#It is calculated by multiplying corresponding components of the vectors and then summing those products.
# Your code here

vector1 = np.array([1, 2, 3])
vector2 = np.array([4, 5, 6])

# Calculate dot product using NumPy
dot_product_numpy = np.dot(vector1, vector2)



print(f"Dot product using NumPy: {dot_product_numpy}")
# Out:
# Dot product using NumPy: 32

# %%
# Cell 2: Cosine Similarity Implementation

# Implement cosine similarity using the dot product
def cosine_similarity(v1, v2):
    dot_product = np.dot(v1, v2)
    norm_v1 = np.linalg.norm(v1)
    norm_v2 = np.linalg.norm(v2)
    return dot_product / (norm_v1 * norm_v2)


# Example vectors
vector_a = np.array([1, 2, 3])
vector_b = np.array([4, 5, 6])

similarity = cosine_similarity(vector_a, vector_b)
print(f"Cosine similarity: {similarity}")
# Out:
# Cosine similarity: 0.9746318461970762

# %%
# !pip install sentence-transformers

import numpy as np
from sentence_transformers import SentenceTransformer

# Load a more advanced pre-trained model
model = SentenceTransformer('all-MiniLM-L6-v2')

def get_sentence_embedding(sentence):
    return model.encode(sentence)

def cosine_similarity(v1, v2):
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

def dot_product_similarity(v1, v2):
    return np.dot(v1, v2)

# Function to compare sentences
def compare_sentences(sentence1, sentence2):
    embedding1 = get_sentence_embedding(sentence1)
    embedding2 = get_sentence_embedding(sentence2)

    cosine_sim = cosine_similarity(embedding1, embedding2)
    dot_sim = dot_product_similarity(embedding1, embedding2)

    print(f"Sentence 1: '{sentence1}'")
    print(f"Sentence 2: '{sentence2}'")
    print(f"Cosine similarity: {cosine_sim:.4f}")
    print(f"Dot product similarity: {dot_sim:.4f}")
    print()

# Example usage
compare_sentences("I love programming", "I enjoy coding")
compare_sentences("Dogs are better than cats", "Cat is funny!")
compare_sentences("I love pizza", "I hate vegetables")
compare_sentences("I'm a doctor", "Sell some phones!")

# Task for users:
print("Now it's your turn! Try comparing different sentences and have fun exploring similarities!")

print("1. Compare sentences with similar meanings but different words.")
compare_sentences("He is very intelligent", "She is extremely smart")
compare_sentences("I am feeling great today", "Today, I feel wonderful")

print("2. Try sentences with the same words in different orders.")
compare_sentences("I have a book", "A book I have")
print("3. Experiment with sentences from different domains or languages.")

compare_sentences("I love programming", "انا احب البرمجة")  # English to ِArabic
compare_sentences("Cooking requires patience", "The universe is vast and mysterious")

# Reflection questions:
print("\nReflection questions:")

print("1. How do cosine similarity and dot product similarity yield identical results in the given examples? What does this reveal about their mathematical properties?")
print("Cosine similarity and dot product similarity can yield identical or nearly identical results under certain conditions due to their mathematical properties. Here’s a detailed explanation:")
{"Conditions for Identical Results"
"Cosine similarity and dot product similarity can yield identical results when the magnitudes of the vectors are 1 (i.e., they are unit vectors) "
"or when comparing proportional vectors. Here’s why:"

"1.Unit Vectors:"
"When both vectors are unit vectors, their magnitudes are 1."
"2.Proportional Vectors:"

}
print("Cosine similarity and dot product measure different aspects of vector similarity."
"Cosine similarity normalizes the vectors to focus on direction, while the dot product considers both direction and magnitude."
 "When vectors are normalized or proportional, their cosine similarity and dot product might appear similar, but in general,"
"they provide different insights into vector relationships.")

print("2. What types of sentences seem to have high similarity? Low similarity?")
print("Types of low similarity: 1.Paraphrases:"

"2.Negation and Contradiction:")

print("Types of Sentences with High Similarity:"
"1.Different Word Usage"
"2.Unrelated Topics:")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 3.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate correlated random points
mean = [0, 0]
cov = [[1, 0.8], [0.8, 1]]  # Covariance matrix with correlation
points = np.random.multivariate_normal(mean, cov, 100)
X = points[:, 0].T
y = points[:, 1].T

# Plot the data points
plt.scatter(X, y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Correlated Random Points')
plt.show()

# Create the design matrix [X 1]
X_design = np.vstack([X, np.ones_like(X)]).T

# Calculate the pseudo-inverse
X_pseudo_inv = np.linalg.pinv(X_design)


# Calculate the coefficients
coefficients = X_pseudo_inv.dot(y)


# Print the coefficients
print(f"Estimated coefficients: {coefficients.flatten()}")

# Plot the results
plt.scatter(X, y, label='Data points')
plt.plot(X, X_design.dot(coefficients), color='red', label='Linear model')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression using Pseudo-Inverse')
plt.show()
# Out:
# Estimated coefficients: [ 0.7907594  -0.09477268]

# %%
import torch

# Create tensors
tensor1 = torch.tensor([1, 2, 3,4])
tensor2 = torch.tensor([4, 5, 6,8])

# Basic operations
print("Addition:", tensor1 + tensor2)
print("Multiplication:", tensor1 * tensor2)

# Concatenation
concat_result = torch.cat((tensor1, tensor2))
print("Concatenation:", concat_result)

# Reshape
reshaped = concat_result.reshape(2, 4)
print("Reshaped tensor:")
print(reshaped)

# Plot a PyTorch tensor
plt.plot(tensor1.numpy(), tensor2.numpy()**2, 'ro-')
plt.xlabel('Tensor 1')
plt.ylabel('Tensor 2')
plt.title('PyTorch Tensor Plot')
plt.show()

# Task for students:
# 1. Create two 2D tensors and perform matrix multiplication
# 2. Use torch.randn() to create a random tensor and calculate its mean and standard deviation
# Out:
# Addition: tensor([ 5,  7,  9, 12])
# Multiplication: tensor([ 4, 10, 18, 32])
# Concatenation: tensor([1, 2, 3, 4, 4, 5, 6, 8])
# Reshaped tensor:
# tensor([[1, 2, 3, 4],
#         [4, 5, 6, 8]])
